# %% [markdown]
# ## Get data

# %%
from get_data import get_dataset, plot_doodles

label_dict = {0: 'apple', 1: 'banana'}
(X_train, y_train), (X_val, y_val), (X_test, y_test) = get_dataset(label_dict.values())

print(f"Loaded {X_train.shape[0]} training samples, {X_val.shape[0]} validation samples and {X_test.shape[0]} test samples")
print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
# Out:
# Loaded 1200 training samples, 400 validation samples and 400 test samples
# X_train shape: (1200, 28, 28), y_train shape: (1200,)

# %%
plot_doodles(X_train, y_train, label_dict, n_rows=6)

# %% [markdown]
# ## Træn model
# Før du går videre med koden skal du definere din model arkitektur i filen `model.py`. Du kan også ændre på data preprocessing i `data.py` filen. Når du har gjort det kan du køre følgende kode for at træne din model.
#
# Du kan altid ændre på model arkitekturen og data preprocessing og træne modellen igen efter du har set på resultaterne.
